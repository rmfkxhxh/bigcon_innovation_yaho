# %%
import pandas as pd
import numpy as np

# %%
data_1=pd.read_pickle('sex_age_move')
data_2=pd.read_pickle('Timemove')
data_3=pd.read_pickle('movedata_worker')

# %%
data_people=data_1

# %%
data_1.columns
data_people=pd.DataFrame()
for i in range(8):
    data_1['FLOW_POP_CON_{}0'.format(i)]=data_1[data_1.columns[i+4]]+data_1[data_1.columns[i+12]]

# %%
data_1.columns
# Out:
# Index(['STD_YM', 'STD_YMD', 'HDONG_CD', 'HDONG_NM', 'MAN_FLOW_POP_CNT_00',
#        'MAN_FLOW_POP_CNT_10', 'MAN_FLOW_POP_CNT_20', 'MAN_FLOW_POP_CNT_30',
#        'MAN_FLOW_POP_CNT_40', 'MAN_FLOW_POP_CNT_50', 'MAN_FLOW_POP_CNT_60',
#        'MAN_FLOW_POP_CNT_70U', 'WMAN_FLOW_POP_CNT_00', 'WMAN_FLOW_POP_CNT_10',
#        'WMAN_FLOW_POP_CNT_20', 'WMAN_FLOW_POP_CNT_30', 'WMAN_FLOW_POP_CNT_40',
#        'WMAN_FLOW_POP_CNT_50', 'WMAN_FLOW_POP_CNT_60', 'WMAN_FLOW_POP_CNT_70U',
#        'SUM', 'MEAN', 'FLOW_POP_CON_00', 'FLOW_POP_CON_10', 'FLOW_POP_CON_20',
#        'FLOW_POP_CON_30', 'FLOW_POP_CON_40', 'FLOW_POP_CON_50',
#        'FLOW_POP_CON_60', 'FLOW_POP_CON_70'],
#       dtype='object')

# %%
data_resut=data_1[['STD_YM', 'STD_YMD', 'HDONG_CD', 'HDONG_NM', 'FLOW_POP_CON_00', 'FLOW_POP_CON_10', 'FLOW_POP_CON_20',
       'FLOW_POP_CON_30', 'FLOW_POP_CON_40', 'FLOW_POP_CON_50',
       'FLOW_POP_CON_60', 'FLOW_POP_CON_70',
       'SUM', 'MEAN']]

# %%
data_resut.to_pickle('basic_move')

# %%
data_resut['SUM-WORKER']=data_resut['SUM']-data_3['WORKER']
# Out:
# C:\Users\Chacrew\Anaconda3\envs\chacrew\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_3[data_3['HDONG_NM']=='가회동']
# Out:
#        STD_YMD HDONG_NM  TMST_05  TMST_06  TMST_07  TMST_08  TMST_09  TMST_10  \
# 7     20180401      가회동   143.52   248.11   320.00   640.94   866.80  1092.78
# 43    20180402      가회동   402.88  1378.52  4841.15  3285.50  2226.66  1877.89
# 79    20180403      가회동   383.18  1303.49  4803.54  3512.37  2357.51  2088.04
# 115   20180404      가회동   341.77  1235.94  4669.63  3474.37  2175.07  1951.45
# 151   20180405      가회동   349.81  1253.23  4627.74  3536.24  2349.54  1896.95
# 187   20180406      가회동   342.80  1232.31  4580.31  3289.61  2248.25  2013.01
# 223   20180407      가회동   224.09   331.56   526.90  1263.74  1597.71  1599.60
# 259   20180408      가회동   143.80   247.42   375.61   688.09  1295.10  1567.86
# 295   20180409      가회동   407.43  1352.38  4873.82  3352.63  2233.62  1805.47
# 331   20180410      가회동   383.02  1286.82  4848.46  3660.77  2530.55  2252.92
# 367   20180411      가회동   340.07  1319.02  4906.26  3438.26  2408.32  2249.31
# ...

# %%
32139.29-3945.957908*2
# Out:
# 24247.374184

# %%
data_resut.to_pickle('real_move.pickle')
